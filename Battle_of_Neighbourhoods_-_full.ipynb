# %% [markdown]
# ## Introduction

# %% [markdown]
# A customer of mine would like to open an Seafood Restaurant in Arhus, Denmark. He work in the seafood business in the Faroe Islands and want to sell their best products seafood to Denmark. As young I studied in Aarhus and like the atmosphere of the town centre, so I have recommended that my customer finds a location in Aarhus, Denmark.
#
# I will try to find a spot for his seafood restaurant from several criteria:
# 1. That is there must be some interesting venues close to it. That is, it must be located in an area belonging to the right cluster.
# 2. It should be far away from other seafood restaurants
# 3. It should be in an area without many other food venues
#
# I will make visualize all food venues and all seafood restaurants and find spots that fullfill criterias 2. and 3.
#
# To obtain criteria 1, I will separate Aarhus center in a mesh of neighbourhoods around 300 metres wide. I will look at the different neighbourhoods to see wich ones are similar in order to find a suitable location. Specifically I will make a clustering of the neighbourhoods based on venues. For instance if there are clusters with theaters or cinemas in them. I will make an k-means clustering analysis using Foursquare API.

# %% [markdown]
# ## Data

# %% [markdown]
# In order to make our analysis we need to obtain some data:
# - We need to construct a mesh of areas covering the center of Aarhus, Denmark
# - From these locations we obtain Forusquare venue data of food venues and seafood restaurant venues, and visualize them

# %% [markdown]
# ### We find the center of Aarhus (Arhus Cathedral)

# %% [markdown]
# First we import packages to handle folium.

# %%
import requests
#!pip install geopy

from geopy.geocoders import Nominatim
geolocator = Nominatim()
adresse = 'Aarhus Domkirke'
try:
    location = geolocator.geocode(adresse)
    print('Arhus Centrum is in ', location.latitude, location.longitude)
except:
    print(adresse)
aarhus_centrum = [location.latitude, location.longitude]
print(aarhus_centrum)
# Out:
# /resources/common/.virtualenv/python3/lib/python3.5/site-packages/ipykernel/__main__.py:5: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
# Arhus Centrum is in  56.15685435 10.2106463239974
# [56.15685435, 10.2106463239974]

# %% [markdown]
# ### We make a mesh of neighbourhoods

# %% [markdown]
# #### First we convert from latitude/longitude to cartesian measures

# %%
#!pip install shapely
import shapely.geometry

#!pip install pyproj
import pyproj

import math

def lonlat_to_xy(lon, lat):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
    return xy[0], xy[1]

def xy_to_lonlat(x, y):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
    return lonlat[0], lonlat[1]

def calc_xy_distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return math.sqrt(dx*dx + dy*dy)

print('Coordinate transformation check')
print('-------------------------------')
print('Aarhus Centrum longitude={}, latitude={}'.format(aarhus_centrum[1], aarhus_centrum[0]))
x, y = lonlat_to_xy(aarhus_centrum[1], aarhus_centrum[0])
print('Aarhus centrum UTM X={}, Y={}'.format(x, y))
lo, la = xy_to_lonlat(x, y)
print('Aarhus centrum longitude={}, latitude={}'.format(lo, la))
# Out:
# Coordinate transformation check
# -------------------------------
# Aarhus Centrum longitude=10.2106463239974, latitude=56.15685435
# Aarhus centrum UTM X=202641.0637672961, Y=6233869.4107194785
# Aarhus centrum longitude=10.210646323997398, latitude=56.15685435000001

# %% [markdown]
# #### Then we construct the neighbourhood centers

# %%
aarhus_centrum_x, aarhus_centrum_y = lonlat_to_xy(aarhus_centrum[1], aarhus_centrum[0]) # City center in Cartesian coordinates

k = math.sqrt(3) / 2 # Vertical offset for hexagonal grid cells
x_min = aarhus_centrum_x - 1800  # we start 1.800 metres from the center
x_step = 300
y_min = aarhus_centrum_y - 1800 - (int(22/k)*k*300 - 3600)/2
y_step = 300 * k 

latitudes = []
longitudes = []
distances_from_center = []
xs = []
ys = []
for i in range(0, int(22/k)):
    y = y_min + i * y_step
    x_offset = 150 if i%2==0 else 0
    for j in range(0, 10):                      # the steps stop at 10 because wa have seawater to the east
        x = x_min + j * x_step + x_offset
        distance_from_center = calc_xy_distance(aarhus_centrum_x, aarhus_centrum_y, x, y)
        if (distance_from_center <= 1801):      # only append points within the 1.800 meter radius
            lon, lat = xy_to_lonlat(x, y)
            latitudes.append(lat)
            longitudes.append(lon)
            distances_from_center.append(distance_from_center)
            xs.append(x)
            ys.append(y)

print(len(latitudes), 'candidate neighbourhood centers generated.')
# Out:
# 116 candidate neighbourhood centers generated.

# %% [markdown]
# #### The neighbourhood centers are plotted

# %%
#!pip install folium
import folium

# %%
map_aarhus = folium.Map(location=aarhus_centrum, zoom_start=13)
folium.Marker(aarhus_centrum, popup='Aarhus Domkirke').add_to(map_aarhus)
for lat, lon in zip(latitudes, longitudes):
    folium.CircleMarker([lat, lon], radius=2, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_aarhus) 
map_aarhus
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### The locations are imported to a dataframe

# %%
import pandas as pd

df_locations = pd.DataFrame({'Neighbourhood Latitude': latitudes,
                             'Neighbourhood Longitude': longitudes,
                             'X': xs,
                             'Y': ys})

df_locations.head()
# Out:
#    Neighbourhood Latitude  Neighbourhood Longitude              X  \
# 0               56.141454                10.205314  202191.063767
# 1               56.141641                10.210125  202491.063767
# 2               56.141828                10.214936  202791.063767
# 3               56.142014                10.219747  203091.063767
# 4               56.143499                10.197807  201741.063767
#
#               Y
# 0  6.232181e+06
# 1  6.232181e+06
# 2  6.232181e+06
# 3  6.232181e+06
# 4  6.232440e+06

# %% [markdown]
# ### Foursquare venue information is collected

# %% [markdown]
# #### We set up to import Foursquare venue information

# %%
CLIENT_ID = '1APIKEUUY3N0O0CG22IPYPWFVL33NLZPJN4RVSHXBO315QIS' # your Foursquare ID
CLIENT_SECRET = 'Y21WCG50Q5S4VLNYQOFIUQ1IHBSQTDUWLDS0NVQX1QBXIDQU' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

food_category = '4d4b7105d754a06374d81259'
seafood_category = '4bf58dd8d48988d1ce941735'

#!pip install foursquare
import foursquare
from pandas.io.json import json_normalize
# Out:
# Your credentails:
# CLIENT_ID: 1APIKEUUY3N0O0CG22IPYPWFVL33NLZPJN4RVSHXBO315QIS
# CLIENT_SECRET:Y21WCG50Q5S4VLNYQOFIUQ1IHBSQTDUWLDS0NVQX1QBXIDQU

# %% [markdown]
# #### We make a function to call the Foursquare venue information

# %%
def getNearbyVenues(latitudes, longitudes, category, radius=170, LIMIT=100):  #radius = 170 to get an overlap
    venues_list=[]
    for lat, lng in zip(latitudes, longitudes):
        #print(lat)
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&categoryId={}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            category,
            radius, 
            LIMIT)
        results = requests.get(url).json()["response"]['groups'][0]['items']
        venues_list.append([(
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### We find all food related venues

# %%
food_venues = getNearbyVenues(latitudes, longitudes, food_category)
food_venues.head()
# Out:
#    Neighbourhood Latitude  Neighbourhood Longitude              Venue  \
# 0               56.143499                10.197807          Go' Kaffe
# 1               56.143687                10.202619  Marselis Pizzeria
# 2               56.143874                10.207430           Aspendos
# 3               56.143874                10.207430  Marselis Pizzeria
# 4               56.145732                10.195111              GLAD!
#
#    Venue Latitude  Venue Longitude Venue Category
# 0       56.144753        10.198304           Café
# 1       56.143119        10.205162    Pizza Place
# 2       56.143428        10.205480    Pizza Place
# 3       56.143119        10.205162    Pizza Place
# 4       56.146910        10.194773    Salad Place

# %%
seafood_venues = getNearbyVenues(latitudes, longitudes, seafood_category)
seafood_venues.head()
# Out:
#    Neighbourhood Latitude  Neighbourhood Longitude                Venue  \
# 0               56.157830                10.205688               Gambas
# 1               56.157830                10.205688           Sushimania
# 2               56.158017                10.210501  Restaurant Pihlkjær
# 3               56.160250                10.207805        Klassisk Fisk
# 4               56.160250                10.207805               Gambas
#
#    Venue Latitude  Venue Longitude      Venue Category
# 0       56.158891        10.206710  Seafood Restaurant
# 1       56.158264        10.207182  Seafood Restaurant
# 2       56.158595        10.212578  Seafood Restaurant
# 3       56.160552        10.209099  Seafood Restaurant
# 4       56.158891        10.206710  Seafood Restaurant

# %% [markdown]
# ### Food venues and seafood restaurants are plotted (seafood restaurants are red)

# %%
map_aarhus = folium.Map(location=aarhus_centrum, zoom_start=14)
folium.Marker(aarhus_centrum, popup='Aarhus Domkirke').add_to(map_aarhus)
for res in food_venues.values:
    lat = res[3]; lon = res[4]
    folium.CircleMarker([lat, lon], radius=2, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_aarhus) 
for res in seafood_venues.values:
    lat = res[3]; lon = res[4]
    folium.CircleMarker([lat, lon], radius=2, color='red', fill=True, fill_color='red', fill_opacity=1).add_to(map_aarhus)   
map_aarhus
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### And the same map with the areas

# %%
map_aarhus = folium.Map(location=aarhus_centrum, zoom_start=14)
folium.Marker(aarhus_centrum, popup='Aarhus Domkirke').add_to(map_aarhus)
for res in food_venues.values:
    lat = res[3]; lon = res[4]
    folium.CircleMarker([lat, lon], radius=2, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_aarhus) 
for res in seafood_venues.values:
    lat = res[3]; lon = res[4]
    folium.CircleMarker([lat, lon], radius=2, color='red', fill=True, fill_color='red', fill_opacity=1).add_to(map_aarhus)   
for lat, lon in zip(latitudes, longitudes):
    folium.Circle([lat, lon], radius=150, color='grey', fill=False).add_to(map_aarhus)
map_aarhus
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### At end we find all venues in each area

# %%
def getAllNearbyVenues(latitudes, longitudes, radius=170, LIMIT=100):  #radius = 170 to get an overlap
    venues_list=[]
    for lat, lng in zip(latitudes, longitudes):
        #print(lat)
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng,
            radius, 
            LIMIT)
        results = requests.get(url).json()["response"]['groups'][0]['items']
        venues_list.append([(
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

all_venues = getAllNearbyVenues(latitudes, longitudes)
all_venues.head()
# Out:
#    Neighbourhood Latitude  Neighbourhood Longitude                  Venue  \
# 0               56.143499                10.197807       Ingerslev Marked
# 1               56.143499                10.197807   Aarhus Svømmestadion
# 2               56.143499                10.197807          ASA Boldbaner
# 3               56.143499                10.197807  Frederiksbjerg Hallen
# 4               56.143499                10.197807              Go' Kaffe
#
#    Venue Latitude  Venue Longitude  Venue Category
# 0       56.144833        10.196892  Farmers Market
# 1       56.143656        10.196837        Gym Pool
# 2       56.143486        10.197621    Soccer Field
# 3       56.143818        10.196807         Stadium
# 4       56.144753        10.198304            Café

# %% [markdown]
# These venues we will use to make a k-means cluster analysis of all the neighbourhoods. All venues are visualized in the map below.

# %%
map_aarhus = folium.Map(location=aarhus_centrum, zoom_start=14)
folium.Marker(aarhus_centrum, popup='Aarhus Domkirke').add_to(map_aarhus)
for res in all_venues.values:
    lat = res[3]; lon = res[4]
    folium.CircleMarker([lat, lon], radius=2, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_aarhus) 
for res in seafood_venues.values:
    lat = res[3]; lon = res[4]
    folium.CircleMarker([lat, lon], radius=2, color='red', fill=True, fill_color='red', fill_opacity=1).add_to(map_aarhus)   
map_aarhus
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Analysis

# %% [markdown]
#  - Make a k-means analysis. Analyse the clusters, in order to find a suitable cluster to locate a new seafood restaurant.
#  - Find a spot away fram other seafood restaurants.
#  - Find a spot not crowded with food venues.

# %% [markdown]
# ### Hot encoding

# %%
# one hot encoding
aarhus_onehot = pd.get_dummies(all_venues[['Venue Category']], prefix="", prefix_sep="")

# %%
# add neighbourhood column back to dataframe
aarhus_onehot['Neighbourhood Latitude'] = all_venues['Neighbourhood Latitude']

# %%
# move neighbourhood column to the first column
fixed_columns = [aarhus_onehot.columns[-1]] + list(aarhus_onehot.columns[:-1])
aarhus_onehot = aarhus_onehot[fixed_columns]

# %%
# Normalize the data
aarhus_grouped = aarhus_onehot.groupby('Neighbourhood Latitude').mean().reset_index()

# %%
#Frequency of top 10 venues
num_top_venues = 10

for hood in aarhus_grouped['Neighbourhood Latitude']:
    print("----"+str(hood)+"----")
    temp = aarhus_grouped[aarhus_grouped['Neighbourhood Latitude'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----56.14349921975371----
#             venue  freq
# 0    Soccer Field   0.2
# 1            Café   0.2
# 2         Stadium   0.2
# 3        Gym Pool   0.2
# 4  Farmers Market   0.2
# 5      Playground   0.0
# 6     Pizza Place   0.0
# 7            Pier   0.0
# 8        Pharmacy   0.0
# 9     Music Venue   0.0
#
#
# ----56.14368651429262----
#                    venue  freq
# 0            Pizza Place   0.5
# 1   Gym / Fitness Center   0.5
# 2    American Restaurant   0.0
# 3            Music Venue   0.0
# 4                   Pool   0.0
# 5                  Plaza   0.0
# 6             Playground   0.0
# 7                   Pier   0.0
# 8               Pharmacy   0.0
# 9  Performing Arts Venue   0.0
#
#
# ----56.14387362193484----
#                    venue  freq
# 0            Pizza Place  0.50
# 1              Jazz Club  0.25
# 2             Playground  0.25
# 3    American Restaurant  0.00
# 4            Music Venue  0.00
# 5                   Pool  0.00
# 6                  Plaza  0.00
# 7                   Pier  0.00
# 8               Pharmacy  0.00
# 9  Performing Arts Venue  0.00
#
#
# ----56.14554400499086----
#                    venue  freq
# 0                  Plaza   1.0
# 1    American Restaurant   0.0
# 2                   Port   0.0
# 3                   Pool   0.0
# 4             Playground   0.0
# 5            Pizza Place   0.0
# 6                   Pier   0.0
# 7               Pharmacy   0.0
# 8  Performing Arts Venue   0.0
# 9       Pedestrian Plaza   0.0
#
#
# ----56.145731596231954----
#                 venue  freq
# 0  Italian Restaurant   0.2
# 1               Plaza   0.2
# 2      Farmers Market   0.2
# 3         Salad Place   0.2
# 4         Music Store   0.2
# 5           Nightclub   0.0
# 6                Pool   0.0
# 7          Playground   0.0
# 8         Pizza Place   0.0
# 9                Pier   0.0
#
#
# ----56.145919000567346----
#          venue  freq
# 0          Pub  0.25
# 1         Café  0.25
# 2          Bar  0.25
# 3   Skate Park  0.25
# 4         Pool  0.00
# 5        Plaza  0.00
# 6   Playground  0.00
# 7  Pizza Place  0.00
# 8         Pier  0.00
# 9    Nightclub  0.00
#
#
# ----56.146106217992276----
#                    venue  freq
# 0           Dessert Shop   0.2
# 1            Coffee Shop   0.2
# 2                   Park   0.2
# 3          Grocery Store   0.2
# 4                 Bakery   0.2
# 5       Pedestrian Plaza   0.0
# 6  Performing Arts Venue   0.0
# 7               Pharmacy   0.0
# 8                   Pier   0.0
# 9            Pizza Place   0.0
#
#
# ----56.146293248501976----
#                    venue  freq
# 0             Playground   1.0
# 1    American Restaurant   0.0
# 2                   Port   0.0
# 3                   Pool   0.0
# 4                  Plaza   0.0
# 5            Pizza Place   0.0
# 6                   Pier   0.0
# 7               Pharmacy   0.0
# 8  Performing Arts Venue   0.0
# 9       Pedestrian Plaza   0.0
#
#
# ----56.14815142190015----
#                            venue  freq
# 0                           Café  0.22
# 1                    Coffee Shop  0.11
# 2  Vegetarian / Vegan Restaurant  0.11
# 3             Italian Restaurant  0.11
# 4       Mediterranean Restaurant  0.11
# 5               Greek Restaurant  0.11
# 6                  Grocery Store  0.11
# 7        Scandinavian Restaurant  0.11
# 8            American Restaurant  0.00
# 9                           Park  0.00
#
#
# ----56.148338749124704----
#                      venue  freq
# 0                     Café  0.25
# 1                   Bakery  0.15
# 2              Coffee Shop  0.10
# 3      American Restaurant  0.05
# 4         Sushi Restaurant  0.05
# 5             Cocktail Bar  0.05
# 6            Grocery Store  0.05
# 7  Scandinavian Restaurant  0.05
# 8        French Restaurant  0.05
# 9                 Beer Bar  0.05
#
#
# ----56.14852588942028----
#                   venue  freq
# 0             Juice Bar  0.17
# 1             Bookstore  0.17
# 2        Cosmetics Shop  0.17
# 3        Sandwich Place  0.17
# 4        Clothing Store  0.17
# 5  Gym / Fitness Center  0.17
# 6   American Restaurant  0.00
# 7              Pharmacy  0.00
# 8                  Park  0.00
# 9      Pedestrian Plaza  0.00
#
#
# ----56.14871284278208----
#                      venue  freq
# 0  Scandinavian Restaurant   1.0
# 1      American Restaurant   0.0
# 2              Music Venue   0.0
# 3                     Pool   0.0
# 4                    Plaza   0.0
# 5               Playground   0.0
# 6              Pizza Place   0.0
# 7                     Pier   0.0
# 8                 Pharmacy   0.0
# 9    Performing Arts Venue   0.0
#
#
# ----56.15019615429725----
#                    venue  freq
# 0            Flea Market   1.0
# 1    American Restaurant   0.0
# 2                   Port   0.0
# 3                   Pool   0.0
# 4                  Plaza   0.0
# 5             Playground   0.0
# 6            Pizza Place   0.0
# 7                   Pier   0.0
# 8               Pharmacy   0.0
# 9  Performing Arts Venue   0.0
#
#
# ----56.15057121531749----
#                            venue  freq
# 0                    Supermarket  0.25
# 1                       Bus Stop  0.25
# 2                          Hotel  0.25
# 3      Middle Eastern Restaurant  0.25
# 4            American Restaurant  0.00
# 5  Paper / Office Supplies Store  0.00
# 6                           Park  0.00
# 7               Pedestrian Plaza  0.00
# 8          Performing Arts Venue  0.00
# 9                       Pharmacy  0.00
#
#
# ----56.15075846541586----
#             venue  freq
# 0     Coffee Shop  0.11
# 1       Juice Bar  0.07
# 2  Sandwich Place  0.07
# 3            Café  0.07
# 4           Hotel  0.07
# 5       Multiplex  0.07
# 6      Steakhouse  0.07
# 7       Bookstore  0.04
# 8      Restaurant  0.04
# 9    Dessert Shop  0.04
#
#
# ----56.15094552856668----
#                            venue  freq
# 0                       Gym Pool  0.25
# 1          Vietnamese Restaurant  0.25
# 2                          Hotel  0.25
# 3          Street Food Gathering  0.25
# 4          Performing Arts Venue  0.00
# 5                      Nightclub  0.00
# 6              Outdoor Sculpture  0.00
# 7  Paper / Office Supplies Store  0.00
# 8                           Park  0.00
# 9               Pedestrian Plaza  0.00
#
#
# ----56.15113240476521----
#                    venue  freq
# 0            Film Studio  0.75
# 1            Music Venue  0.25
# 2                   Port  0.00
# 3                   Pool  0.00
# 4                  Plaza  0.00
# 5             Playground  0.00
# 6            Pizza Place  0.00
# 7                   Pier  0.00
# 8               Pharmacy  0.00
# 9  Performing Arts Venue  0.00
#
#
# ----56.15242833585502----
#                            venue  freq
# 0                     Hobby Shop  0.33
# 1                    Coffee Shop  0.33
# 2  Paper / Office Supplies Store  0.33
# 3            American Restaurant  0.00
# 4                    Music Venue  0.00
# 5                           Pool  0.00
# 6                          Plaza  0.00
# 7                     Playground  0.00
# 8                    Pizza Place  0.00
# 9                           Pier  0.00
#
#
# ----56.15261606968138----
#                  venue  freq
# 0           Skate Park  0.25
# 1          Event Space  0.25
# 2                 Café  0.25
# 3          Music Venue  0.25
# 4  American Restaurant  0.00
# 5                 Pool  0.00
# 6                Plaza  0.00
# 7           Playground  0.00
# 8          Pizza Place  0.00
# 9                 Pier  0.00
#
#
# ----56.152803616556----
#                            venue  freq
# 0                    Music Venue   0.4
# 1                            Gym   0.2
# 2                          Hotel   0.2
# 3                  Bowling Alley   0.2
# 4                      Nightclub   0.0
# 5              Outdoor Sculpture   0.0
# 6  Paper / Office Supplies Store   0.0
# 7                           Park   0.0
# 8               Pedestrian Plaza   0.0
# 9            American Restaurant   0.0
#
#
# ----56.15299097647406----
#                              venue  freq
# 0                              Pub  0.14
# 1                      Music Venue  0.14
# 2                             Park  0.07
# 3                Outdoor Sculpture  0.07
# 4                             Café  0.07
# 5            Performing Arts Venue  0.07
# 6                      Beer Garden  0.07
# 7                     Concert Hall  0.07
# 8  Molecular Gastronomy Restaurant  0.07
# 9                            Plaza  0.07
#
#
# ----56.15317814943083----
#                            venue  freq
# 0                            Pub  0.12
# 1          Vietnamese Restaurant  0.12
# 2                          Hotel  0.12
# 3                      Gift Shop  0.12
# 4               Pedestrian Plaza  0.12
# 5                      Roof Deck  0.12
# 6        Scandinavian Restaurant  0.12
# 7                    Coffee Shop  0.12
# 8          Performing Arts Venue  0.00
# 9  Paper / Office Supplies Store  0.00
#
#
# ----56.15336513542152----
#                   venue  freq
# 0                 Hotel  0.17
# 1   American Restaurant  0.08
# 2            Steakhouse  0.08
# 3                Lounge  0.08
# 4  Gym / Fitness Center  0.08
# 5           Music Venue  0.08
# 6     French Restaurant  0.08
# 7                  Café  0.08
# 8                   Pub  0.08
# 9    Italian Restaurant  0.08
#
#
# ----56.15355193444138----
#                  venue  freq
# 0                 Café   0.5
# 1            Cafeteria   0.5
# 2  American Restaurant   0.0
# 3                  Pub   0.0
# 4            Pool Hall   0.0
# 5                 Pool   0.0
# 6                Plaza   0.0
# 7           Playground   0.0
# 8          Pizza Place   0.0
# 9                 Pier   0.0
#
#
# ----56.1539249715496----
#                    venue  freq
# 0        Harbor / Marina   1.0
# 1    American Restaurant   0.0
# 2            Music Venue   0.0
# 3                   Pool   0.0
# 4                  Plaza   0.0
# 5             Playground   0.0
# 6            Pizza Place   0.0
# 7                   Pier   0.0
# 8               Pharmacy   0.0
# 9  Performing Arts Venue   0.0
#
#
# ----56.15466045241----
#                    venue  freq
# 0   Gym / Fitness Center   1.0
# 1    American Restaurant   0.0
# 2            Music Venue   0.0
# 3                   Pool   0.0
# 4                  Plaza   0.0
# 5             Playground   0.0
# 6            Pizza Place   0.0
# 7                   Pier   0.0
# 8               Pharmacy   0.0
# 9  Performing Arts Venue   0.0
#
#
# ----56.15484829610054----
#                            venue  freq
# 0           Arts & Entertainment  0.33
# 1                     Restaurant  0.33
# 2                  Grocery Store  0.33
# 3            American Restaurant  0.00
# 4          Performing Arts Venue  0.00
# 5              Outdoor Sculpture  0.00
# 6  Paper / Office Supplies Store  0.00
# 7                           Park  0.00
# 8               Pedestrian Plaza  0.00
# 9                           Pier  0.00
#
#
# ----56.155223422580264----
#                   venue  freq
# 0                  Café  0.22
# 1              Wine Bar  0.11
# 2  Fast Food Restaurant  0.11
# 3                  Park  0.11
# 4          Concert Hall  0.11
# 5             Jazz Club  0.11
# 6            Art Museum  0.11
# 7     Outdoor Sculpture  0.11
# 8                  Pool  0.00
# 9             Pool Hall  0.00
#
#
# ----56.155410705359905----
#                              venue  freq
# 0                              Pub  0.12
# 1                     Burger Joint  0.12
# 2          Scandinavian Restaurant  0.12
# 3                French Restaurant  0.06
# 4                      Beer Garden  0.06
# 5                      Coffee Shop  0.06
# 6                        Gastropub  0.06
# 7  Southern / Soul Food Restaurant  0.06
# 8             Gym / Fitness Center  0.06
# 9                             Café  0.06
#
#
# ----56.155597801159686----
#                     venue  freq
# 0                     Bar  0.14
# 1            Cocktail Bar  0.11
# 2            Burger Joint  0.07
# 3    Gym / Fitness Center  0.07
# 4  Furniture / Home Store  0.07
# 5             Coffee Shop  0.07
# 6                    Café  0.07
# 7                   Plaza  0.04
# 8               Roof Deck  0.04
# 9       French Restaurant  0.04
#
#
# ----56.155784709974874----
#                      venue  freq
# 0                      Bar   0.2
# 1               Steakhouse   0.2
# 2  Scandinavian Restaurant   0.2
# 3       Italian Restaurant   0.1
# 4                  Gay Bar   0.1
# 5              Music Venue   0.1
# 6                  Theater   0.1
# 7                     Pier   0.0
# 8                 Pharmacy   0.0
# 9              Pizza Place   0.0
#
#
# ----56.15597143180069----
#                    venue  freq
# 0                   Port   1.0
# 1    American Restaurant   0.0
# 2                   Pool   0.0
# 3                  Plaza   0.0
# 4             Playground   0.0
# 5            Pizza Place   0.0
# 6                   Pier   0.0
# 7               Pharmacy   0.0
# 8  Performing Arts Venue   0.0
# 9       Pedestrian Plaza   0.0
#
#
# ----56.15745580371984----
#                    venue  freq
# 0      Convenience Store   0.2
# 1                   Café   0.2
# 2       Asian Restaurant   0.2
# 3                    Bar   0.2
# 4            Supermarket   0.2
# 5                   Pier   0.0
# 6                   Park   0.0
# 7       Pedestrian Plaza   0.0
# 8  Performing Arts Venue   0.0
# 9               Pharmacy   0.0
#
#
# ----56.157643196339265----
#                         venue  freq
# 0                        Café  0.18
# 1                 Coffee Shop  0.12
# 2            Sushi Restaurant  0.12
# 3                   Nightclub  0.06
# 4                         Bar  0.06
# 5                 Music Store  0.06
# 6              Sandwich Place  0.06
# 7  Modern European Restaurant  0.06
# 8                 Supermarket  0.06
# 9                  Restaurant  0.06
#
#
# ----56.157830401965086----
#             venue  freq
# 0        Wine Bar  0.14
# 1        Tea Room  0.14
# 2            Café  0.14
# 3     Coffee Shop  0.14
# 4     Supermarket  0.14
# 5  Sandwich Place  0.14
# 6           Plaza  0.14
# 7        Pharmacy  0.00
# 8            Pier  0.00
# 9       Nightclub  0.00
#
#
# ----56.15801742059251----
#                      venue  freq
# 0        French Restaurant  0.20
# 1                     Café  0.13
# 2              Coffee Shop  0.07
# 3                    Plaza  0.07
# 4                      Bar  0.07
# 5                    Hotel  0.03
# 6           Clothing Store  0.03
# 7                 Pharmacy  0.03
# 8  Scandinavian Restaurant  0.03
# 9                   Museum  0.03
#
#
# ----56.158204252216784----
#                    venue  freq
# 0             Food Court   1.0
# 1    American Restaurant   0.0
# 2                   Port   0.0
# 3                   Pool   0.0
# 4                  Plaza   0.0
# 5             Playground   0.0
# 6            Pizza Place   0.0
# 7                   Pier   0.0
# 8               Pharmacy   0.0
# 9  Performing Arts Venue   0.0
#
#
# ----56.158390896833154----
#                    venue  freq
# 0             Public Art   1.0
# 1    American Restaurant   0.0
# 2            Music Venue   0.0
# 3                   Pool   0.0
# 4                  Plaza   0.0
# 5             Playground   0.0
# 6            Pizza Place   0.0
# 7                   Pier   0.0
# 8               Pharmacy   0.0
# 9  Performing Arts Venue   0.0
#
#
# ----56.15857735443687----
#                  venue  freq
# 0        Boat or Ferry   1.0
# 1  American Restaurant   0.0
# 2          Music Venue   0.0
# 3            Pool Hall   0.0
# 4                 Pool   0.0
# 5                Plaza   0.0
# 6           Playground   0.0
# 7          Pizza Place   0.0
# 8                 Pier   0.0
# 9             Pharmacy   0.0
#
#
# ----56.15931255392272----
#                  venue  freq
# 0   Falafel Restaurant   0.5
# 1               Bakery   0.5
# 2  American Restaurant   0.0
# 3          Music Venue   0.0
# 4                 Pool   0.0
# 5                Plaza   0.0
# 6           Playground   0.0
# 7          Pizza Place   0.0
# 8                 Pier   0.0
# 9             Pharmacy   0.0
#
#
# ----56.15950043039933----
#                            venue  freq
# 0                       Bus Stop  0.25
# 1                        Theater  0.25
# 2                 History Museum  0.25
# 3                  Historic Site  0.25
# 4            American Restaurant  0.00
# 5                       Pharmacy  0.00
# 6  Paper / Office Supplies Store  0.00
# 7                           Park  0.00
# 8               Pedestrian Plaza  0.00
# 9          Performing Arts Venue  0.00
#
#
# ----56.15968811987811----
#                            venue  freq
# 0               Botanical Garden   0.2
# 1                    Art Gallery   0.2
# 2                           Café   0.2
# 3                 History Museum   0.2
# 4                            Bar   0.2
# 5                       Pharmacy   0.0
# 6  Paper / Office Supplies Store   0.0
# 7                           Park   0.0
# 8               Pedestrian Plaza   0.0
# 9          Performing Arts Venue   0.0
#
#
# ----56.160062937823035----
#                      venue  freq
# 0                     Café   0.4
# 1                 Wine Bar   0.2
# 2           Sandwich Place   0.2
# 3  Scandinavian Restaurant   0.2
# 4                     Port   0.0
# 5                     Pool   0.0
# 6                    Plaza   0.0
# 7               Playground   0.0
# 8              Pizza Place   0.0
# 9                     Pier   0.0
#
#
# ----56.160250066279644----
#                 venue  freq
# 0                Café  0.19
# 1            Wine Bar  0.10
# 2          Restaurant  0.10
# 3    Sushi Restaurant  0.05
# 4         Supermarket  0.05
# 5  Seafood Restaurant  0.05
# 6      Sandwich Place  0.05
# 7           Nightclub  0.05
# 8      Ice Cream Shop  0.05
# 9               Hotel  0.05
#
#
# ----56.160437007719324----
#                            venue  freq
# 0              French Restaurant  0.33
# 1                            Bar  0.17
# 2                     Restaurant  0.17
# 3                    Salad Place  0.17
# 4             Mexican Restaurant  0.17
# 5                       Pharmacy  0.00
# 6  Paper / Office Supplies Store  0.00
# 7                           Park  0.00
# 8               Pedestrian Plaza  0.00
# 9          Performing Arts Venue  0.00
#
#
# ----56.1606237621373----
#                   venue  freq
# 0  Fast Food Restaurant  0.25
# 1       Harbor / Marina  0.25
# 2                  Pier  0.25
# 3  Gym / Fitness Center  0.25
# 4   American Restaurant  0.00
# 5             Nightclub  0.00
# 6                  Pool  0.00
# 7                 Plaza  0.00
# 8            Playground  0.00
# 9           Pizza Place  0.00
#
#
# ----56.16081032952885----
#                            venue  freq
# 0                  Boat or Ferry   0.7
# 1                Harbor / Marina   0.2
# 2                    Coffee Shop   0.1
# 3                           Pier   0.0
# 4  Paper / Office Supplies Store   0.0
# 5                           Park   0.0
# 6               Pedestrian Plaza   0.0
# 7          Performing Arts Venue   0.0
# 8                       Pharmacy   0.0
# 9            American Restaurant   0.0
#
#
# ----56.1609967098892----
#                  venue  freq
# 0                 Café   0.5
# 1        Boat or Ferry   0.5
# 2  American Restaurant   0.0
# 3            Nightclub   0.0
# 4            Pool Hall   0.0
# 5                 Pool   0.0
# 6                Plaza   0.0
# 7           Playground   0.0
# 8          Pizza Place   0.0
# 9                 Pier   0.0
#
#
# ----56.16173257167424----
#                   venue  freq
# 0    Falafel Restaurant  0.25
# 1  Fast Food Restaurant  0.25
# 2                Bakery  0.25
# 3                  Park  0.25
# 4   American Restaurant  0.00
# 5             Nightclub  0.00
# 6                  Pool  0.00
# 7                 Plaza  0.00
# 8            Playground  0.00
# 9           Pizza Place  0.00
#
#
# ----56.161920371040466----
#                  venue  freq
# 0     Botanical Garden   0.5
# 1        Movie Theater   0.5
# 2  American Restaurant   0.0
# 3            Pool Hall   0.0
# 4                 Pool   0.0
# 5                Plaza   0.0
# 6           Playground   0.0
# 7          Pizza Place   0.0
# 8                 Pier   0.0
# 9             Pharmacy   0.0
#
#
# ----56.16266969829364----
#                    venue  freq
# 0             Playground   0.5
# 1                    Gym   0.5
# 2    American Restaurant   0.0
# 3            Music Venue   0.0
# 4                   Pool   0.0
# 5                  Plaza   0.0
# 6            Pizza Place   0.0
# 7                   Pier   0.0
# 8               Pharmacy   0.0
# 9  Performing Arts Venue   0.0
#
#
# ----56.16285656253017----
#                   venue  freq
# 0         Design Studio   0.2
# 1            Restaurant   0.2
# 2                 Plaza   0.2
# 3  Fast Food Restaurant   0.2
# 4                   Bar   0.2
# 5     Outdoor Sculpture   0.0
# 6             Pool Hall   0.0
# 7                  Pool   0.0
# 8            Playground   0.0
# 9           Pizza Place   0.0
#
#
# ----56.16304323972648----
#                  venue  freq
# 0   Athletics & Sports   0.5
# 1              Brewery   0.5
# 2  American Restaurant   0.0
# 3            Nightclub   0.0
# 4            Pool Hall   0.0
# 5                 Pool   0.0
# 6                Plaza   0.0
# 7           Playground   0.0
# 8          Pizza Place   0.0
# 9                 Pier   0.0
#
#
# ----56.1632297298778----
#                    venue  freq
# 0                   Pool  0.29
# 1         Scenic Lookout  0.29
# 2            Coffee Shop  0.14
# 3                  Beach  0.14
# 4              Beach Bar  0.14
# 5                   Park  0.00
# 6       Pedestrian Plaza  0.00
# 7  Performing Arts Venue  0.00
# 8               Pharmacy  0.00
# 9    American Restaurant  0.00
#
#
# ----56.16415255719221----
#                    venue  freq
# 0                   Park   1.0
# 1    American Restaurant   0.0
# 2                   Port   0.0
# 3                   Pool   0.0
# 4                  Plaza   0.0
# 5             Playground   0.0
# 6            Pizza Place   0.0
# 7                   Pier   0.0
# 8               Pharmacy   0.0
# 9  Performing Arts Venue   0.0
#
#
# ----56.164527814638106----
#                    venue  freq
# 0            Pizza Place   1.0
# 1    American Restaurant   0.0
# 2                   Port   0.0
# 3                   Pool   0.0
# 4                  Plaza   0.0
# 5             Playground   0.0
# 6                   Pier   0.0
# 7               Pharmacy   0.0
# 8  Performing Arts Venue   0.0
# 9       Pedestrian Plaza   0.0
#
#
# ----56.16471516280386----
#                    venue  freq
# 0                 Garden   0.5
# 1         Science Museum   0.5
# 2    American Restaurant   0.0
# 3                   Pool   0.0
# 4                  Plaza   0.0
# 5             Playground   0.0
# 6            Pizza Place   0.0
# 7                   Pier   0.0
# 8               Pharmacy   0.0
# 9  Performing Arts Venue   0.0
#
#
# ----56.164902323925126----
#                    venue  freq
# 0                   Park   1.0
# 1    American Restaurant   0.0
# 2                   Port   0.0
# 3                   Pool   0.0
# 4                  Plaza   0.0
# 5             Playground   0.0
# 6            Pizza Place   0.0
# 7                   Pier   0.0
# 8               Pharmacy   0.0
# 9  Performing Arts Venue   0.0
#
#
# ----56.165276085015144----
#                            venue  freq
# 0                    Fish Market  0.33
# 1                            Bar  0.17
# 2                    Supermarket  0.17
# 3                     Restaurant  0.17
# 4                        Brewery  0.17
# 5  Paper / Office Supplies Store  0.00
# 6                           Park  0.00
# 7               Pedestrian Plaza  0.00
# 8          Performing Arts Venue  0.00
# 9                       Pharmacy  0.00
#
#
# ----56.16546268497435----
#                  venue  freq
# 0      Harbor / Marina  0.50
# 1          Fish Market  0.25
# 2    French Restaurant  0.25
# 3  American Restaurant  0.00
# 4            Nightclub  0.00
# 5                 Pool  0.00
# 6                Plaza  0.00
# 7           Playground  0.00
# 8          Pizza Place  0.00
# 9                 Pier  0.00
#
#
# ----56.16564909787004----
#                    venue  freq
# 0   Gym / Fitness Center   1.0
# 1    American Restaurant   0.0
# 2            Music Venue   0.0
# 3                   Pool   0.0
# 4                  Plaza   0.0
# 5             Playground   0.0
# 6            Pizza Place   0.0
# 7                   Pier   0.0
# 8               Pharmacy   0.0
# 9  Performing Arts Venue   0.0
#
#
# ----56.16657251046667----
#                    venue  freq
# 0             Restaurant   1.0
# 1    American Restaurant   0.0
# 2            Music Venue   0.0
# 3                   Pool   0.0
# 4                  Plaza   0.0
# 5             Playground   0.0
# 6            Pizza Place   0.0
# 7                   Pier   0.0
# 8               Pharmacy   0.0
# 9  Performing Arts Venue   0.0
#
#
# ----56.16694761361165----
#                  venue  freq
# 0          Beer Garden   1.0
# 1  American Restaurant   0.0
# 2          Music Venue   0.0
# 3            Pool Hall   0.0
# 4                 Pool   0.0
# 5                Plaza   0.0
# 6           Playground   0.0
# 7          Pizza Place   0.0
# 8                 Pier   0.0
# 9             Pharmacy   0.0
#
#
# ----56.16713488459911----
#                    venue  freq
# 0         Science Museum   1.0
# 1    American Restaurant   0.0
# 2            Music Venue   0.0
# 3                   Pool   0.0
# 4                  Plaza   0.0
# 5             Playground   0.0
# 6            Pizza Place   0.0
# 7                   Pier   0.0
# 8               Pharmacy   0.0
# 9  Performing Arts Venue   0.0
#
#
# ----56.167882097870965----
#                            venue  freq
# 0                Harbor / Marina   0.4
# 1                    Sports Club   0.2
# 2             Athletics & Sports   0.2
# 3                   Fishing Spot   0.2
# 4                       Pharmacy   0.0
# 5  Paper / Office Supplies Store   0.0
# 6                           Park   0.0
# 7               Pedestrian Plaza   0.0
# 8          Performing Arts Venue   0.0
# 9            American Restaurant   0.0
#
#
# ----56.16899243148769----
#                    venue  freq
# 0                    Gym   1.0
# 1    American Restaurant   0.0
# 2            Music Venue   0.0
# 3                   Pool   0.0
# 4                  Plaza   0.0
# 5             Playground   0.0
# 6            Pizza Place   0.0
# 7                   Pier   0.0
# 8               Pharmacy   0.0
# 9  Performing Arts Venue   0.0
#
#
# ----56.16917999943034----
#                  venue  freq
# 0                  Bar   1.0
# 1  American Restaurant   0.0
# 2          Music Venue   0.0
# 3            Pool Hall   0.0
# 4                 Pool   0.0
# 5                Plaza   0.0
# 6           Playground   0.0
# 7          Pizza Place   0.0
# 8                 Pier   0.0
# 9             Pharmacy   0.0
#
#
# ----56.16936738030095----
#                    venue  freq
# 0                   Park   1.0
# 1    American Restaurant   0.0
# 2                   Port   0.0
# 3                   Pool   0.0
# 4                  Plaza   0.0
# 5             Playground   0.0
# 6            Pizza Place   0.0
# 7                   Pier   0.0
# 8               Pharmacy   0.0
# 9  Performing Arts Venue   0.0
#
#
# ----56.16992840043278----
#                 venue  freq
# 0  Italian Restaurant  0.14
# 1     Thai Restaurant  0.14
# 2      Discount Store  0.14
# 3    Greek Restaurant  0.14
# 4           Multiplex  0.14
# 5                Café  0.14
# 6            Pharmacy  0.14
# 7         Pizza Place  0.00
# 8                Pier  0.00
# 9   Outdoor Sculpture  0.00
#
#
# ----56.17011503296751----
#                  venue  freq
# 0      Harbor / Marina   0.5
# 1       Scenic Lookout   0.5
# 2  American Restaurant   0.0
# 3          Music Venue   0.0
# 4                 Pool   0.0
# 5                Plaza   0.0
# 6           Playground   0.0
# 7          Pizza Place   0.0
# 8                 Pier   0.0
# 9             Pharmacy   0.0
#
#
# ----56.17030147840635----
#                            venue  freq
# 0                    Sports Club  0.25
# 1                  Boat or Ferry  0.25
# 2                     Bike Trail  0.25
# 3                   Fishing Spot  0.25
# 4          Performing Arts Venue  0.00
# 5              Outdoor Sculpture  0.00
# 6  Paper / Office Supplies Store  0.00
# 7                           Park  0.00
# 8               Pedestrian Plaza  0.00
# 9                       Pharmacy  0.00
#
#
# ----56.171599811015994----
#                            venue  freq
# 0                            Bar  0.33
# 1                  Deli / Bodega  0.33
# 2                 Student Center  0.33
# 3                       Pharmacy  0.00
# 4              Outdoor Sculpture  0.00
# 5  Paper / Office Supplies Store  0.00
# 6                           Park  0.00
# 7               Pedestrian Plaza  0.00
# 8          Performing Arts Venue  0.00
# 9            American Restaurant  0.00
#
#
# ----56.17178711469608----
#                  venue  freq
# 0             Bus Stop   1.0
# 1  American Restaurant   0.0
# 2            Nightclub   0.0
# 3            Pool Hall   0.0
# 4                 Pool   0.0
# 5                Plaza   0.0
# 6           Playground   0.0
# 7          Pizza Place   0.0
# 8                 Pier   0.0
# 9             Pharmacy   0.0
#
#
# ----56.171974231280785----
#                  venue  freq
# 0       Cosmetics Shop   0.5
# 1        Grocery Store   0.5
# 2  American Restaurant   0.0
# 3          Music Venue   0.0
# 4                 Pool   0.0
# 5                Plaza   0.0
# 6           Playground   0.0
# 7          Pizza Place   0.0
# 8                 Pier   0.0
# 9             Pharmacy   0.0
#
#
# ----56.172161160765356----
#                  venue  freq
# 0       Cosmetics Shop  0.33
# 1          Supermarket  0.33
# 2         Burger Joint  0.33
# 3  American Restaurant  0.00
# 4            Nightclub  0.00
# 5                 Pool  0.00
# 6                Plaza  0.00
# 7           Playground  0.00
# 8          Pizza Place  0.00
# 9                 Pier  0.00
#
#
# ----56.172347903145----
#                            venue  freq
# 0                    Pizza Place  0.25
# 1                           Café  0.25
# 2                  Grocery Store  0.25
# 3  Paper / Office Supplies Store  0.25
# 4            American Restaurant  0.00
# 5                    Music Venue  0.00
# 6                           Pool  0.00
# 7                          Plaza  0.00
# 8                     Playground  0.00
# 9                           Pier  0.00

# %% [markdown]
# As we can see there are neighbourhoods with very few venues in them.

# %% [markdown]
# ### We run the k-means algorithm for different number of k's

# %%
# Define function that return most common venues 
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]
from pylab import *

# %%
# Top 10 venues are returned
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood Latitude']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighbourhoods_venues_sorted = pd.DataFrame(columns=columns)
neighbourhoods_venues_sorted['Neighbourhood Latitude'] = aarhus_grouped['Neighbourhood Latitude']

for ind in np.arange(aarhus_grouped.shape[0]):
    neighbourhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(aarhus_grouped.iloc[ind, :], num_top_venues)
    
aarhus_grouped_clustering = aarhus_grouped.drop('Neighbourhood Latitude', 1)

# %% [markdown]
# #### The graphs of the two different number of top venues are plotted

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

# %% [markdown]
# The graphs show sum of squared distances from the centroids for different k's. One graph is for 'top 10 venues' and the other for 'top 5 venues'.

# %%
sse = []
list_k = list(range(1, 30))

for k in list_k:
    km = KMeans(n_clusters=k)
    km.fit(aarhus_grouped_clustering)
    sse.append(km.inertia_)

# %%
import matplotlib.pyplot as plt
# Plot sse against k
plt.figure(figsize=(6, 6))
plt.plot(list_k, sse)   #, '-o')
plt.xlabel(r'Number of clusters *k*')
plt.ylabel('Sum of squared distance');

# %% [markdown]
# There is no "elbow" on the graph, so it is difficult to see an optimal number for 'k'. We shall use the clusters to find a good placement for a restaurant, so the number of clusters must not be too small. On the other hand it makes no sence to have too many clusters. There fore I will settle for 10 clusters.

# %% [markdown]
# ### Wa make 10 clusters based on top 10 venues in each neighbourhood

# %%
# set number of clusters
kclusters = 10

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(aarhus_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([5, 3, 7, 4, 5, 5, 5, 9, 5, 5], dtype=int32)

# %%
# add clustering labels
neighbourhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

aarhus_merged = df_locations

# merge aarhus_grouped with aarhus_data to add latitude/longitude for each neighbourhood
aarhus_merged = aarhus_merged.join(neighbourhoods_venues_sorted.set_index('Neighbourhood Latitude'), on='Neighbourhood Latitude')

# %%
# Neighbourhoods that not are assigned to any cluster are omitted
aarhus_merged = aarhus_merged.dropna()

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

map_clusters = folium.Map(location=aarhus_centrum, zoom_start=14)
folium.Marker(aarhus_centrum, popup='Aarhus Domkirke').add_to(map_aarhus)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, cluster in zip(aarhus_merged['Neighbourhood Latitude'], aarhus_merged['Neighbourhood Longitude'], aarhus_merged['Cluster Labels']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.Circle(
        [lat, lon],
        radius=140,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Cluster 0

# %% [markdown]
# This cluster is a 'park' cluster and probably not suitable for our restaurant.

# %%
aarhus_merged.loc[aarhus_merged['Cluster Labels'] == 0, aarhus_merged.columns[[1] + list(range(5, aarhus_merged.shape[1]))]]
# Out:
#      Neighbourhood Longitude 1st Most Common Venue 2nd Most Common Venue  \
# 86                 10.187969                  Park              Wine Bar
# 90                 10.207224                  Park              Wine Bar
# 105                10.201829                  Park              Wine Bar
#
#     3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 86       Department Store          Dessert Shop        Discount Store
# 90       Department Store          Dessert Shop        Discount Store
# 105      Department Store          Dessert Shop        Discount Store
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 86            Event Space    Falafel Restaurant        Farmers Market
# 90            Event Space    Falafel Restaurant        Farmers Market
# 105           Event Space    Falafel Restaurant        Farmers Market
#
#     9th Most Common Venue 10th Most Common Venue
# 86   Fast Food Restaurant            Film Studio
# 90   Fast Food Restaurant            Film Studio
# 105  Fast Food Restaurant            Film Studio

# %% [markdown]
# ### Cluster 1

# %% [markdown]
# This cluster is a 'park' cluster and probably not suitable for our restaurant.

# %%
aarhus_merged.loc[aarhus_merged['Cluster Labels'] == 1, aarhus_merged.columns[[1] + list(range(5, aarhus_merged.shape[1]))]]
# Out:
#     Neighbourhood Longitude 1st Most Common Venue 2nd Most Common Venue  \
# 49                10.189135  Arts & Entertainment            Restaurant
# 73                10.212618     French Restaurant           Salad Place
# 83                10.214735                 Plaza         Design Studio
# 95                10.190084            Restaurant              Wine Bar
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 49         Grocery Store              Wine Bar     French Restaurant
# 73            Restaurant    Mexican Restaurant                   Bar
# 83            Restaurant                   Bar  Fast Food Restaurant
# 95     French Restaurant         Design Studio          Dessert Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 49          Dessert Shop        Discount Store           Event Space
# 73  Fast Food Restaurant           Flea Market          Fishing Spot
# 83     French Restaurant          Dessert Shop        Discount Store
# 95        Discount Store           Event Space    Falafel Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 49    Falafel Restaurant         Farmers Market
# 73           Fish Market            Film Studio
# 83           Event Space     Falafel Restaurant
# 95        Farmers Market   Fast Food Restaurant

# %% [markdown]
# ### Cluster 2

# %% [markdown]
# This cluster is close to the harbour. There are several wine bars in the area. Even though there is french restaurants in the area I think this is not a good location for our seafood restaurant.

# %%
aarhus_merged.loc[aarhus_merged['Cluster Labels'] == 2, aarhus_merged.columns[[1] + list(range(5, aarhus_merged.shape[1]))]]
# Out:
#      Neighbourhood Longitude 1st Most Common Venue 2nd Most Common Venue  \
# 47                 10.225519       Harbor / Marina              Wine Bar
# 93                 10.221666       Harbor / Marina           Fish Market
# 102                10.223783       Harbor / Marina           Sports Club
# 109                10.221087       Harbor / Marina        Scenic Lookout
#
#       3rd Most Common Venue 4th Most Common Venue   5th Most Common Venue  \
# 47   Furniture / Home Store          Dessert Shop          Discount Store
# 93        French Restaurant              Wine Bar  Furniture / Home Store
# 102      Athletics & Sports          Fishing Spot                Wine Bar
# 109                Wine Bar     French Restaurant           Design Studio
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 47            Event Space    Falafel Restaurant        Farmers Market
# 93           Dessert Shop        Discount Store           Event Space
# 102           Film Studio            Food Court           Flea Market
# 109          Dessert Shop        Discount Store           Event Space
#
#     9th Most Common Venue 10th Most Common Venue
# 47   Fast Food Restaurant            Film Studio
# 93     Falafel Restaurant         Farmers Market
# 102           Fish Market         Farmers Market
# 109    Falafel Restaurant         Farmers Market

# %% [markdown]
# ### Cluster 3

# %% [markdown]
# In this cluster we see Gym/Fitness Centers as most common venues. Also it is vera far from town center. Probably not an interesting spot for our restaurant.

# %%
aarhus_merged.loc[aarhus_merged['Cluster Labels'] == 3, aarhus_merged.columns[[1] + list(range(5, aarhus_merged.shape[1]))]]
# Out:
#     Neighbourhood Longitude 1st Most Common Venue 2nd Most Common Venue  \
# 5                 10.202619           Pizza Place  Gym / Fitness Center
# 48                10.184322  Gym / Fitness Center              Wine Bar
# 94                10.226480  Gym / Fitness Center              Wine Bar
#
#      3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 5                 Wine Bar     French Restaurant          Dessert Shop
# 48  Furniture / Home Store          Dessert Shop        Discount Store
# 94  Furniture / Home Store          Dessert Shop        Discount Store
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 5         Discount Store           Event Space    Falafel Restaurant
# 48           Event Space    Falafel Restaurant        Farmers Market
# 94           Event Space    Falafel Restaurant        Farmers Market
#
#    9th Most Common Venue 10th Most Common Venue
# 5         Farmers Market   Fast Food Restaurant
# 48  Fast Food Restaurant            Film Studio
# 94  Fast Food Restaurant            Film Studio

# %% [markdown]
# ### Cluster 4

# %% [markdown]
# There is not much more than a plaza at this venue. There it is omitted.

# %%
aarhus_merged.loc[aarhus_merged['Cluster Labels'] == 4, aarhus_merged.columns[[1] + list(range(5, aarhus_merged.shape[1]))]]
# Out:
#     Neighbourhood Longitude 1st Most Common Venue 2nd Most Common Venue  \
# 11                  10.1903                 Plaza              Wine Bar
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 11      Department Store          Dessert Shop        Discount Store
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 11           Event Space    Falafel Restaurant        Farmers Market
#
#    9th Most Common Venue 10th Most Common Venue
# 11  Fast Food Restaurant            Film Studio

# %% [markdown]
# ### Cluster 5

# %% [markdown]
# In this cluster we see "normal" venues for a town center. Most common venues are shops, hotels, eateries and cafes. This cluster is placed in the center of Aarhus. This area could be a good placement for the seafood restaurant, but a drawback could be that the area is crowded with restaurants.

# %%
aarhus_merged.loc[aarhus_merged['Cluster Labels'] == 5, aarhus_merged.columns[[1] + list(range(5, aarhus_merged.shape[1]))]]
# Out:
#      Neighbourhood Longitude    1st Most Common Venue  \
# 4                  10.197807                     Café
# 12                 10.195111                    Plaza
# 13                 10.199922               Skate Park
# 14                 10.204734             Dessert Shop
# 22                 10.197226                     Café
# 23                 10.202038                     Café
# 24                 10.206849                Bookstore
# 25                 10.211661  Scandinavian Restaurant
# 30                 10.189717              Flea Market
# 32                 10.199341                    Hotel
# 33                 10.204153              Coffee Shop
# 34                 10.208965    Vietnamese Restaurant
# 35                 10.213777              Film Studio
# 39                 10.187020               Hobby Shop
# 40                 10.191832               Skate Park
# 41                 10.196644              Music Venue
# 42                 10.201457              Music Venue
# 43                 10.206269         Pedestrian Plaza
# 44                 10.211081                    Hotel
# 45                 10.215894                     Café
# 51                 10.198760                     Café
# 52                 10.203572                      Pub
# 53                 10.208385                      Bar
# 54                 10.213198               Steakhouse
# 55                 10.218011                     Port
# 60                 10.196062        Convenience Store
# 61                 10.200875                     Café
# 62                 10.205688                 Wine Bar
# 63                 10.210501        French Restaurant
# 64                 10.215314               Food Court
# 65                 10.220127               Public Art
# 67                 10.183739       Falafel Restaurant
# 68                 10.188552           History Museum
# 69                 10.193365                      Bar
# 71                 10.202991                     Café
# 72                 10.207805                     Café
# 74                 10.217431          Harbor / Marina
# 77                 10.185854       Falafel Restaurant
# 78                 10.190667            Movie Theater
# 84                 10.219548       Athletics & Sports
# 85                 10.224362                     Pool
# 89                 10.202410           Science Museum
# 92                 10.216852              Fish Market
# 98                 10.204526           Science Museum
# 104                10.197014                      Bar
# 108                10.216272                Multiplex
# 110                10.225901            Boat or Ferry
# 111                10.199131            Deli / Bodega
# 112                10.203945                 Bus Stop
# 114                10.213575           Cosmetics Shop
#
#        2nd Most Common Venue            3rd Most Common Venue  \
# 4               Soccer Field                         Gym Pool
# 12        Italian Restaurant                   Farmers Market
# 13                       Bar                              Pub
# 14               Coffee Shop                           Bakery
# 22             Grocery Store    Vegetarian / Vegan Restaurant
# 23                    Bakery                      Coffee Shop
# 24            Clothing Store                   Cosmetics Shop
# 25                  Wine Bar                French Restaurant
# 30                  Wine Bar                 Department Store
# 32                  Bus Stop        Middle Eastern Restaurant
# 33                 Multiplex                   Sandwich Place
# 34                  Gym Pool            Street Food Gathering
# 35               Music Venue                         Wine Bar
# 39               Coffee Shop    Paper / Office Supplies Store
# 40               Event Space                             Café
# 41                     Hotel                              Gym
# 42                       Pub  Molecular Gastronomy Restaurant
# 43                 Gift Shop                            Hotel
# 44       American Restaurant                              Pub
# 45                 Cafeteria                         Wine Bar
# 51                  Wine Bar                     Concert Hall
# 52              Burger Joint          Scandinavian Restaurant
# 53              Cocktail Bar                             Café
# 54   Scandinavian Restaurant                              Bar
# 55             Deli / Bodega                    Design Studio
# 60          Asian Restaurant                      Supermarket
# 61               Coffee Shop                 Sushi Restaurant
# 62                  Tea Room                      Coffee Shop
# 63                      Café                              Bar
# 64                  Wine Bar                 Department Store
# 65                  Wine Bar                French Restaurant
# 67                    Bakery                         Wine Bar
# 68             Historic Site                          Theater
# 69            History Museum                             Café
# 71                  Wine Bar                   Sandwich Place
# 72                  Wine Bar                       Restaurant
# 74      Gym / Fitness Center                             Pier
# 77      Fast Food Restaurant                           Bakery
# 78          Botanical Garden                         Wine Bar
# 84                   Brewery                         Wine Bar
# 85            Scenic Lookout                      Coffee Shop
# 89                    Garden                         Wine Bar
# 92               Supermarket                          Brewery
# 98                  Wine Bar                French Restaurant
# 104                 Wine Bar                           Garden
# 108           Discount Store                         Pharmacy
# 110               Bike Trail                      Sports Club
# 111           Student Center                              Bar
# 112                 Wine Bar           Furniture / Home Store
# 114              Supermarket                     Burger Joint
#
#        4th Most Common Venue    5th Most Common Venue   6th Most Common Venue  \
# 4                    Stadium           Farmers Market             Film Studio
# 12               Salad Place              Music Store              Food Court
# 13                      Café               Food Court             Flea Market
# 14             Grocery Store                     Park       French Restaurant
# 22   Scandinavian Restaurant       Italian Restaurant             Coffee Shop
# 23       American Restaurant                 Beer Bar     Japanese Restaurant
# 24      Gym / Fitness Center                Juice Bar          Sandwich Place
# 25             Design Studio             Dessert Shop          Discount Store
# 30              Dessert Shop           Discount Store             Event Space
# 32               Supermarket              Event Space      Falafel Restaurant
# 33                      Café                    Hotel               Juice Bar
# 34                     Hotel            Historic Site         Harbor / Marina
# 35          Department Store             Dessert Shop          Discount Store
# 39         French Restaurant             Dessert Shop          Discount Store
# 40               Music Venue         Department Store            Dessert Shop
# 41             Bowling Alley        French Restaurant            Dessert Shop
# 42                     Plaza               Art Museum   Performing Arts Venue
# 43     Vietnamese Restaurant  Scandinavian Restaurant                     Pub
# 44               Music Venue                     Café                  Lounge
# 45    Furniture / Home Store           Discount Store             Event Space
# 51         Outdoor Sculpture                     Park               Jazz Club
# 52                      Café     Gym / Fitness Center        Sushi Restaurant
# 53      Gym / Fitness Center             Burger Joint             Coffee Shop
# 54                   Theater              Music Venue      Italian Restaurant
# 55              Dessert Shop           Discount Store             Event Space
# 60                      Café                      Bar                Wine Bar
# 61                 Nightclub           Sandwich Place             Music Store
# 62                      Café           Sandwich Place             Supermarket
# 63               Coffee Shop                    Plaza         Thai Restaurant
# 64              Dessert Shop           Discount Store             Event Space
# 65             Design Studio             Dessert Shop          Discount Store
# 67                    Garden             Dessert Shop          Discount Store
# 68                  Bus Stop                 Wine Bar    Fast Food Restaurant
# 69          Botanical Garden              Art Gallery             Event Space
# 71   Scandinavian Restaurant         Department Store            Dessert Shop
# 72        Seafood Restaurant                   Bakery             Coffee Shop
# 74      Fast Food Restaurant                 Wine Bar       French Restaurant
# 77                      Park                 Wine Bar  Furniture / Home Store
# 78    Furniture / Home Store             Dessert Shop          Discount Store
# 84                    Garden           Discount Store             Event Space
# 85                 Beach Bar                    Beach             Film Studio
# 89         French Restaurant            Design Studio            Dessert Shop
# 92                Restaurant                      Bar    Fast Food Restaurant
# 98             Design Studio             Dessert Shop          Discount Store
# 104             Dessert Shop           Discount Store             Event Space
# 108          Thai Restaurant       Italian Restaurant        Greek Restaurant
# 110             Fishing Spot              Fish Market       French Restaurant
# 111               Food Court              Flea Market            Fishing Spot
# 112             Dessert Shop           Discount Store             Event Space
# 114   Furniture / Home Store             Dessert Shop          Discount Store
#
#       7th Most Common Venue     8th Most Common Venue   9th Most Common Venue  \
# 4               Flea Market              Fishing Spot             Fish Market
# 12            Design Studio              Dessert Shop          Discount Store
# 13             Fishing Spot               Fish Market             Film Studio
# 14           Discount Store               Event Space      Falafel Restaurant
# 22         Greek Restaurant  Mediterranean Restaurant    Fast Food Restaurant
# 23            Grocery Store         French Restaurant            Cocktail Bar
# 24              Flea Market              Fishing Spot             Fish Market
# 25              Event Space        Falafel Restaurant          Farmers Market
# 30       Falafel Restaurant            Farmers Market    Fast Food Restaurant
# 32           Farmers Market      Fast Food Restaurant  Furniture / Home Store
# 33               Steakhouse                     Plaza              Restaurant
# 34            Design Studio              Dessert Shop          Discount Store
# 35              Event Space        Falafel Restaurant          Farmers Market
# 39              Event Space        Falafel Restaurant          Farmers Market
# 40           Discount Store        Falafel Restaurant          Farmers Market
# 41           Discount Store               Event Space      Falafel Restaurant
# 42         Asian Restaurant                      Park            Concert Hall
# 43              Coffee Shop                 Roof Deck             Film Studio
# 44               Steakhouse                       Bar       French Restaurant
# 45       Falafel Restaurant            Farmers Market    Fast Food Restaurant
# 51     Fast Food Restaurant                Art Museum          Farmers Market
# 52        French Restaurant                    Bakery             Coffee Shop
# 53   Furniture / Home Store              Gourmet Shop               Roof Deck
# 54                  Gay Bar                  Wine Bar            Fishing Spot
# 55       Falafel Restaurant            Farmers Market    Fast Food Restaurant
# 60              Film Studio                Food Court             Flea Market
# 61               Restaurant                 Juice Bar                     Bar
# 62                    Plaza                       Gym             Fish Market
# 63                Bookstore                  Pharmacy                  Museum
# 64       Falafel Restaurant            Farmers Market    Fast Food Restaurant
# 65              Event Space        Falafel Restaurant          Farmers Market
# 67              Event Space            Farmers Market    Fast Food Restaurant
# 68              Flea Market              Fishing Spot             Fish Market
# 69       Falafel Restaurant            Farmers Market    Fast Food Restaurant
# 71           Discount Store               Event Space      Falafel Restaurant
# 72           Discount Store            Farmers Market           Grocery Store
# 74             Dessert Shop            Discount Store             Event Space
# 77             Dessert Shop            Discount Store             Event Space
# 78              Event Space        Falafel Restaurant          Farmers Market
# 84       Falafel Restaurant            Farmers Market    Fast Food Restaurant
# 85              Flea Market              Fishing Spot             Fish Market
# 89           Discount Store               Event Space      Falafel Restaurant
# 92              Flea Market              Fishing Spot             Film Studio
# 98              Event Space        Falafel Restaurant          Farmers Market
# 104      Falafel Restaurant            Farmers Market    Fast Food Restaurant
# 108                    Café               Film Studio              Food Court
# 110              Food Court               Flea Market             Film Studio
# 111             Fish Market               Film Studio    Fast Food Restaurant
# 112      Falafel Restaurant            Farmers Market    Fast Food Restaurant
# 114             Event Space        Falafel Restaurant          Farmers Market
#
#       10th Most Common Venue
# 4                   Wine Bar
# 12               Event Space
# 13      Fast Food Restaurant
# 14            Farmers Market
# 22              Fishing Spot
# 23   Scandinavian Restaurant
# 24               Film Studio
# 25      Fast Food Restaurant
# 30               Film Studio
# 32               Film Studio
# 33            Clothing Store
# 34               Event Space
# 35      Fast Food Restaurant
# 39      Fast Food Restaurant
# 40      Fast Food Restaurant
# 41            Farmers Market
# 42         Outdoor Sculpture
# 43      Fast Food Restaurant
# 44        Italian Restaurant
# 45               Film Studio
# 51         French Restaurant
# 52               Art Gallery
# 53                   Brewery
# 54               Fish Market
# 55               Film Studio
# 60              Fishing Spot
# 61            Shop & Service
# 62             Design Studio
# 63            Clothing Store
# 64               Film Studio
# 65      Fast Food Restaurant
# 67               Film Studio
# 68               Film Studio
# 69               Film Studio
# 71            Farmers Market
# 72                     Hotel
# 74        Falafel Restaurant
# 77            Farmers Market
# 78      Fast Food Restaurant
# 84               Film Studio
# 85      Fast Food Restaurant
# 89            Farmers Market
# 92                  Wine Bar
# 98      Fast Food Restaurant
# 104              Film Studio
# 108              Flea Market
# 110                   Garden
# 111   Furniture / Home Store
# 112              Film Studio
# 114     Fast Food Restaurant

# %% [markdown]
# ### Cluster 6

# %% [markdown]
# This is the landing quay area, and is not suitable for our restaurant.

# %%
aarhus_merged.loc[aarhus_merged['Cluster Labels'] == 6, aarhus_merged.columns[[1] + list(range(5, aarhus_merged.shape[1]))]]
# Out:
#     Neighbourhood Longitude 1st Most Common Venue 2nd Most Common Venue  \
# 66                10.224941         Boat or Ferry                Garden
# 75                10.222245         Boat or Ferry       Harbor / Marina
# 76                10.227058         Boat or Ferry                  Café
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 66          Dessert Shop        Discount Store           Event Space
# 75           Coffee Shop                Garden        Discount Store
# 76                Garden        Discount Store           Event Space
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 66    Falafel Restaurant        Farmers Market  Fast Food Restaurant
# 75           Event Space    Falafel Restaurant        Farmers Market
# 76    Falafel Restaurant        Farmers Market  Fast Food Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 66           Film Studio            Fish Market
# 75  Fast Food Restaurant            Film Studio
# 76           Film Studio            Fish Market

# %% [markdown]
# ### Cluster 7

# %% [markdown]
# This is a shopping cluster - therefore not very interesting for a restaurant.

# %%
aarhus_merged.loc[aarhus_merged['Cluster Labels'] == 7, aarhus_merged.columns[[1] + list(range(5, aarhus_merged.shape[1]))]]
# Out:
#      Neighbourhood Longitude 1st Most Common Venue 2nd Most Common Venue  \
# 6                  10.207430           Pizza Place            Playground
# 88                 10.197596           Pizza Place              Wine Bar
# 113                10.208760        Cosmetics Shop         Grocery Store
# 115                10.218390           Pizza Place         Grocery Store
#
#     3rd Most Common Venue          4th Most Common Venue  \
# 6               Jazz Club                       Wine Bar
# 88       Department Store                   Dessert Shop
# 113              Wine Bar         Furniture / Home Store
# 115                  Café  Paper / Office Supplies Store
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 6       French Restaurant          Dessert Shop        Discount Store
# 88         Discount Store           Event Space    Falafel Restaurant
# 113          Dessert Shop        Discount Store           Event Space
# 115              Wine Bar     French Restaurant        Discount Store
#
#     8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 6             Event Space    Falafel Restaurant         Farmers Market
# 88         Farmers Market  Fast Food Restaurant            Film Studio
# 113    Falafel Restaurant        Farmers Market   Fast Food Restaurant
# 115           Event Space    Falafel Restaurant         Farmers Market

# %% [markdown]
# ### Cluster 8

# %% [markdown]
# The only thing in this cluster is a beer garden, and this is the univercity campus of Aarhus. Not interesting for a restaurant.

# %%
aarhus_merged.loc[aarhus_merged['Cluster Labels'] == 8, aarhus_merged.columns[[1] + list(range(5, aarhus_merged.shape[1]))]]
# Out:
#     Neighbourhood Longitude 1st Most Common Venue 2nd Most Common Venue  \
# 97                10.199712           Beer Garden              Wine Bar
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 97                Garden          Dessert Shop        Discount Store
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 97           Event Space    Falafel Restaurant        Farmers Market
#
#    9th Most Common Venue 10th Most Common Venue
# 97  Fast Food Restaurant            Film Studio

# %% [markdown]
# ### Cluster 9

# %% [markdown]
# A playground area is not a good location.

# %%
aarhus_merged.loc[aarhus_merged['Cluster Labels'] == 9, aarhus_merged.columns[[1] + list(range(5, aarhus_merged.shape[1]))]]
# Out:
#      Neighbourhood Longitude 1st Most Common Venue 2nd Most Common Venue  \
# 15                 10.209545            Playground              Wine Bar
# 82                 10.209921            Playground                   Gym
# 103                10.192200                   Gym              Wine Bar
#
#       3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 15         Department Store          Dessert Shop        Discount Store
# 82                 Wine Bar     French Restaurant          Dessert Shop
# 103  Furniture / Home Store          Dessert Shop        Discount Store
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 15            Event Space    Falafel Restaurant        Farmers Market
# 82         Discount Store           Event Space    Falafel Restaurant
# 103           Event Space    Falafel Restaurant        Farmers Market
#
#     9th Most Common Venue 10th Most Common Venue
# 15   Fast Food Restaurant            Film Studio
# 82         Farmers Market   Fast Food Restaurant
# 103  Fast Food Restaurant            Film Studio

# %% [markdown]
# We hava analyzed the clusters and come to the conclusion that cluster 4 is the only suitable cluster.

# %% [markdown]
# ## Visualization of feasable clusters and location of competitors

# %%
map_clusters = folium.Map(location=aarhus_centrum, zoom_start=14)
folium.Marker(aarhus_centrum, popup='Aarhus Domkirke').add_to(map_aarhus)

# We visualize feasable clusters
aarhus_merged_2 = aarhus_merged.loc[aarhus_merged['Cluster Labels'] == 5.0]

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, cluster in zip(aarhus_merged_2['Neighbourhood Latitude'], aarhus_merged_2['Neighbourhood Longitude'], aarhus_merged_2['Cluster Labels']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.Circle(
        [lat, lon],
        radius=140,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.5).add_to(map_clusters)
for res in food_venues.values:
    lat = res[3]; lon = res[4]
    folium.Circle([lat, lon], radius=20, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_clusters) 
for res in seafood_venues.values:
    lat = res[3]; lon = res[4]
    folium.Circle([lat, lon], radius=25, color='black', fill=True, fill_color='yellow', fill_opacity=1).add_to(map_clusters)         
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### We analyse the feasable neighbourhoods

# %%
latitudes_2 = aarhus_merged_2['Neighbourhood Latitude'].tolist()
#latitudes_2

# %%
longitudes_2 = aarhus_merged_2['Neighbourhood Longitude'].tolist()
#longitudes_2

# %%
all_venues_2 = getAllNearbyVenues(latitudes_2, longitudes_2)
all_venues.head()
# Out:
#    Neighbourhood Latitude  Neighbourhood Longitude                  Venue  \
# 0               56.143499                10.197807       Ingerslev Marked
# 1               56.143499                10.197807   Aarhus Svømmestadion
# 2               56.143499                10.197807          ASA Boldbaner
# 3               56.143499                10.197807  Frederiksbjerg Hallen
# 4               56.143499                10.197807              Go' Kaffe
#
#    Venue Latitude  Venue Longitude  Venue Category
# 0       56.144833        10.196892  Farmers Market
# 1       56.143656        10.196837        Gym Pool
# 2       56.143486        10.197621    Soccer Field
# 3       56.143818        10.196807         Stadium
# 4       56.144753        10.198304            Café

# %%
all_venues_grouped = all_venues_2.groupby('Neighbourhood Latitude').count().reset_index()
top = all_venues_grouped.sort_values('Neighbourhood Longitude').head(7)
top.sort_index()
# Out:
#     Neighbourhood Latitude  Neighbourhood Longitude  Venue  Venue Latitude  \
# 7                56.148713                        1      1               1
# 8                56.150196                        1      1               1
# 24               56.155971                        1      1               1
# 29               56.158204                        1      1               1
# 30               56.158391                        1      1               1
# 43               56.167135                        1      1               1
# 44               56.169180                        1      1               1
#
#     Venue Longitude  Venue Category
# 7                 1               1
# 8                 1               1
# 24                1               1
# 29                1               1
# 30                1               1
# 43                1               1
# 44                1               1

# %%
top_list = top['Neighbourhood Latitude'].tolist()
top_venues = df_locations.loc[df_locations['Neighbourhood Latitude'].isin(top_list)]
top_venues
# Out:
#      Neighbourhood Latitude  Neighbourhood Longitude              X  \
# 25                56.148713                10.211661  202641.063767
# 30                56.150196                10.189717  201291.063767
# 55                56.155971                10.218011  203091.063767
# 64                56.158204                10.215314  202941.063767
# 65                56.158391                10.220127  203241.063767
# 98                56.167135                10.204526  202341.063767
# 104               56.169180                10.197014  201891.063767
#
#                 Y
# 25   6.232960e+06
# 30   6.233220e+06
# 55   6.233740e+06
# 64   6.233999e+06
# 65   6.233999e+06
# 98   6.235039e+06
# 104  6.235298e+06

# %%
map_aarhus_top = folium.Map(location=aarhus_centrum, zoom_start=14)
folium.Marker(aarhus_centrum, popup='Aarhus Domkirke').add_to(map_aarhus_top)
for res in top_venues.values:
    lat = res[0]; lon = res[1]
    folium.Circle([lat, lon], radius=150, color='blue', fill=True, fill_color='blue', fill_opacity=0.4).add_to(map_aarhus_top) 
for res in seafood_venues.values:
    lat = res[3]; lon = res[4]
    folium.CircleMarker([lat, lon], radius=2, color='red', fill=True, fill_color='red', fill_opacity=1).add_to(map_aarhus_top)   
map_aarhus_top
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Therefore we will recommend to locate the seafood restaurant in the southernmost location.

# %%
best = top_venues.sort_values('Y').head(1)
best
# Out:
#     Neighbourhood Latitude  Neighbourhood Longitude              X  \
# 25               56.148713                10.211661  202641.063767
#
#                Y
# 25  6.232960e+06

# %%
map_aarhus_top = folium.Map(location=aarhus_centrum, zoom_start=14)
folium.Marker(aarhus_centrum, popup='Aarhus Domkirke').add_to(map_aarhus_top)
for res in top_venues.values:
    lat = res[0]; lon = res[1]
    folium.Circle([lat, lon], radius=150, color='blue', fill=True, fill_color='blue', fill_opacity=0.3).add_to(map_aarhus_top) 
for res in seafood_venues.values:
    lat = res[3]; lon = res[4]
    folium.CircleMarker([lat, lon], radius=2, color='red', fill=True, fill_color='red', fill_opacity=1).add_to(map_aarhus_top)   
for res in best.values:
    lat = res[0]; lon = res[1]
    folium.Circle([lat, lon], radius=50, color='black', fill=True, fill_color='yellow', fill_opacity=1).add_to(map_aarhus_top)   

map_aarhus_top
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
aarhus_grouped.shape
# Out:
# (76, 123)

# %% [markdown]
# ## Conclusion and recommendations

# %% [markdown]
# We have found the best spot for the restaurant as the yellow spot above.
